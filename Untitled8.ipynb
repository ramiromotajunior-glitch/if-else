# %% [markdown]
# <a href="https://colab.research.google.com/github/ramiromotajunior-glitch/if-else/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
entrega = input('digite o tipo de entrega:')
if entrega == 'padrão':
  print('entrega padrão:R$10,00')
elif entrega == 'expresso':
  print('entrega expresso : R$ 20,00')

else:
  print('opção de entrega invalida')
# Out:
# digite o tipo de entrega:padrão
# entrega padrão:R$10,00

# %%
# atividade  01
numero =float(input('digite um número:'))
if numero > 0:
   print(' número positivo')
elif numero==0:
   print('número nulo')
else:
  print('número negativo')
# Out:
# digite um número:5
#  número positivo

# %%
numero=int(input('digite seu numero:'))
if numero % 2 == 0 :
  print('o numero é par')
else:
  print('o numero é impar')
# Out:
# digite seu numero:2
# o numero é par

# %%
# atividade 03
nota=float(input('digite sua nota:'))
if nota >=7:
  print('aprovado')
elif nota >= 5:
  print('recuperação')
else:
  print('reprovado')
# Out:
# digite sua nota:8
# aprovado

# %%
# atividade 4
usuario=input('digite seu usuario:')
senha=input('digite bsua senha:')
if usuario == "admin" and senha == "1234":
  print('login relizado com sucesso')
else:
  print('usuario ou senha invalido')
# Out:
# digite seu usuario:1234
# digite bsua senha:1234
# usuario ou senha invalido
